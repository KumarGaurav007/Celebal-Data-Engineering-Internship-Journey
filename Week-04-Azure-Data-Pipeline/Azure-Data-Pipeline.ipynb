# %% [markdown]
# > **Internship:** Celebal Technologies Excellence Internship Program
# > **Domain:** Data Engineering
# > **Week:** 4
# > **Topic:** Azure Cloud Fundamentals and Data Pipeline
# > **Author:** Gaurav Kumar

# %% [markdown]
# # Week 4 Assignment
# ## Azure Cloud Fundamentals and Data Pipeline Implementation using Azure Data Factory (ADF)

# %% [markdown]
# ## Overview
#
# This notebook demonstrates the implementation of a complete cloud-based data pipeline using Microsoft Azure services. The objective is to understand the fundamental concepts of Azure Cloud and build an end-to-end data movement pipeline using Azure Storage Account and Azure Data Factory (ADF).
#
# Throughout this assignment, Azure resources are created and configured to upload data, establish cloud connectivity, build data pipelines, monitor execution, and manage access permissions.
#
# The implementation simulates a real-world data engineering workflow where data is ingested from cloud storage, validated, and copied to a destination using Azure Data Factory.

# %% [markdown]
# ## Objectives
#
# The primary objectives of this assignment are:
#
# - Understand the basic concepts of Microsoft Azure.
# - Create and manage Azure cloud resources.
# - Configure Azure Storage Account and Blob Storage.
# - Upload structured data into Azure Blob Storage.
# - Create and configure Azure Data Factory.
# - Build an automated data pipeline using Copy Data activity.
# - Validate source metadata using Get Metadata activity.
# - Execute and monitor data pipelines.
# - Understand Azure Identity and Access Management (IAM).
# - Gain practical exposure to cloud-based ETL workflows.

# %% [markdown]
# ## Azure Services Used
#
# The following Azure services are utilized during this assignment:
#
# - Azure Resource Group
# - Azure Storage Account
# - Azure Blob Storage
# - Azure Data Factory (ADF)
# - Linked Services
# - Datasets
# - Get Metadata Activity
# - Copy Data Activity
# - Azure IAM (Role-Based Access Control)

# %% [markdown]
# # Task 1 — Create Resource Group
#
# ## Objective
#
# A Resource Group acts as a logical container for Azure resources. It enables centralized management of related cloud services throughout the project lifecycle.
#
# ### Steps Performed
#
# - Logged into Azure Portal.
# - Created a new Resource Group.
# - Selected subscription and region.
# - Assigned a unique Resource Group name.
# - Successfully created the Resource Group.
#
# ### Deliverable
#
# > **Screenshot:** Resource Group successfully created.
#
# ![](./screenshots/resource_group.jpg)
#
# ### Outcome
#
# The Resource Group was successfully created and is ready to host all Azure resources required for the assignment.
#
# ---

# %% [markdown]
# # Task 2 — Azure Storage Account and Blob Storage
#
# ## Objective
#
# Azure Storage Account provides secure cloud storage for structured and unstructured data. Blob Storage is used to store CSV files that serve as the source for Azure Data Factory pipelines.
#
# ### Steps Performed
#
# - Created a Storage Account.
# - Configured basic storage settings.
# - Created a Blob Container.
# - Uploaded the Superstore CSV dataset into the container.
#
# ### Deliverables
#
# > **Screenshot:** Storage Account
#
# ![](./screenshots/storage_account.jpg)
#
# > **Screenshot:** Blob Container
#
# ![](./screenshots/blob_container.jpg)
#
# > **Screenshot:** Uploaded CSV File
#
# ![](./screenshots/uploaded_csv.jpg)
#
#
#
# ### Outcome
#
# The dataset was successfully uploaded to Azure Blob Storage and is available for pipeline processing.
#
# ---

# %% [markdown]
# # Task 3 — Azure Data Factory Configuration
#
# ## Objective
#
# Azure Data Factory (ADF) is Microsoft's cloud-based ETL and data integration service. It enables users to create, schedule, and monitor data pipelines using a visual interface.
#
# ### Steps Performed
#
# - Created Azure Data Factory.
# - Explored the ADF interface:
#   - Author
#   - Monitor
#   - Manage
# - Created a Linked Service connecting Azure Blob Storage.
# - Created Source Dataset.
# - Created Destination Dataset.
# - Configured the Get Metadata activity.
#
# ### Deliverables
#
# > **Screenshot:** Azure Data Factory
#
# ![](./screenshots/azure_data_factory.jpg)
#
# > **Screenshot:** Linked Service
#
# ![](./screenshots/linked_service01.jpg)
#
# ![](./screenshots/linked_service02.jpg)
#
# > **Screenshot:** Source Dataset
#
# ![](./screenshots/source_dataset.jpg)
#
# > **Screenshot:** Destination Dataset
#
# ![](./screenshots/destination_dataset.jpg)
#
# > **Screenshot:** Get Metadata Activity
#
# ![](./screenshots/get_metadata.jpg)
#
#
#
# ### Outcome
#
# Azure Data Factory was successfully configured and connected to Blob Storage.
#
# ---

# %% [markdown]
# # Task 4 — Pipeline Development
#
# ## Objective
#
# The objective of this task is to develop an ETL pipeline that copies data from a source Blob Storage location to a destination location.
#
# ### Steps Performed
#
# - Created a new pipeline.
# - Configured Copy Data activity.
# - Connected Source Dataset.
# - Connected Destination Dataset.
# - Configured Copy activity settings.
# - (Optional) Added ForEach activity for multiple files.
#
# ### Deliverable
#
# > **Screenshot:** Pipeline Design
#
# - Create Copy Data Pipeline
#
# ![](./screenshots/pipeline01.jpg)
#
# - Configure Source Dataset
#
# ![](./screenshots/pipeline02.jpg)
#
# - Configure Destination Dataset
#
# ![](./screenshots/pipeline03.jpg)
#
# ### Outcome
#
# The pipeline was successfully designed and configured for data movement.
#
# ---

# %% [markdown]
# # Task 5 — Pipeline Execution
#
# ## Objective
#
# Execute the pipeline and verify successful data movement between the configured source and destination.
#
# ### Steps Performed
#
# - Executed the pipeline using Debug/Trigger.
# - Monitored pipeline execution.
# - Verified successful execution status.
#
# ### Deliverable
#
# > **Screenshot:** Successful Pipeline Execution
#
# - Verify Pipeline Execution
#
# ![](./screenshots/pipeline_execution01.jpg)
#
# - Verify Output File
#
# ![](./screenshots/pipeline_execution02.jpg)
#
# ### Outcome
#
# The pipeline executed successfully, and data was copied from the source container to the destination container.
#
# ---

# %% [markdown]
# # Task 6 — Identity and Access Management (IAM)
#
# ## Objective
#
# Azure IAM (Identity and Access Management) is used to control access to Azure resources through Role-Based Access Control (RBAC).
#
# ### Steps Performed
#
# - Assigned Reader role.
# - Assigned Contributor role.
# - Granted Azure Data Factory access to Blob Storage.
#
# ### Deliverable
#
# > **Screenshot:** IAM Role Assignment
#
# ![](./screenshots/iam_role_assignment01.jpg)
#
#
# ### Outcome
#
# Role assignments were successfully configured, enabling Azure Data Factory to access Azure Storage resources securely.
#
# ---

# %% [markdown]
# # Mini Project — Customer Data Pipeline using Azure Data Factory
#
# ## Problem Statement
#
# Build a cloud-based data pipeline that reads a CSV dataset from Azure Blob Storage, validates the file using the Get Metadata activity, and copies the data to another Blob Storage location using Azure Data Factory.
#
# ---
#
# ## Architecture
#
# ```
#
# CSV File
#
# ↓
#
# Azure Blob Storage
#
# ↓
#
# Linked Service
#
# ↓
#
# Source Dataset
#
# ↓
#
# Get Metadata
#
# ↓
#
# Copy Data Activity
#
# ↓
#
# Destination Dataset
#
# ↓
#
# Output File
#
# ```
#
# ---
#
# ## Implementation
#
# The implementation consisted of the following stages:
#
# 1. Upload CSV file to Azure Blob Storage.
# 2. Configure Linked Service.
# 3. Create Source Dataset.
# 4. Create Destination Dataset.
# 5. Validate file metadata.
# 6. Execute Copy Data pipeline.
# 7. Verify successful execution.
#
# ---
#
# ## Expected Output
#
# - Pipeline executed successfully.
# - Metadata validated successfully.
# - CSV file copied to destination Blob Storage.
# - Execution monitored through Azure Data Factory.
#
# ---

# %% [markdown]
# # Conclusion
#
# This assignment provided hands-on experience with Microsoft Azure and Azure Data Factory by implementing a complete cloud-based data pipeline.
#
# Throughout the assignment, Azure resources were created and configured, cloud storage was established, data was uploaded to Blob Storage, and Azure Data Factory was used to build and execute an ETL pipeline. The implementation also covered metadata validation, data movement, pipeline monitoring, and access management using Azure IAM.
#
# ## Key Learning Outcomes
#
# - Understood Azure cloud fundamentals.
# - Configured Azure Resource Group and Storage Account.
# - Worked with Azure Blob Storage.
# - Built data pipelines using Azure Data Factory.
# - Configured Linked Services and Datasets.
# - Used Get Metadata and Copy Data activities.
# - Executed and monitored Azure pipelines.
# - Learned Azure Role-Based Access Control (RBAC).
#
# Overall, this assignment demonstrates how Azure services can be integrated to build scalable, secure, and automated cloud-based data pipelines commonly used in modern data engineering solutions.
